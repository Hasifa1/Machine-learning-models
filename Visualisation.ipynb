# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasifa1/Machine-learning-models/blob/main/Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/SUV_Purchase.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=df['Age']
y=df['Purchased']
plt.scatter(x,y)

# %%
sns.scatterplot(x='Age',y='EstimatedSalary',hue='Purchased',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(x='Age',y='EstimatedSalary',hue='Gender',style='Purchased',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.pairplot(df,hue='Purchased')

# %%
df=pd.DataFrame(list(zip(x,y)),columns=['x_vals','y_vals'])
plt.scatter(df.x_vals,df.y_vals)
